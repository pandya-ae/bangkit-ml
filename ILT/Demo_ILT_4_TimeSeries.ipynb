# %% [markdown]
# # Time Series

# %% [markdown]
# This tutorial demonstrates time series forecasting using TensorFlow on sunspots dataset.

# %% [markdown]
# ## Import TensorFlow

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import csv
from tensorflow.keras import layers, models, optimizers

# %% [markdown]
# ## Prepare the dataset for training

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/Sunspots.csv \
    -O /tmp/sunspots.csv
# Out:
# --2022-04-04 10:26:33--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/Sunspots.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.133.128, 74.125.140.128, 108.177.15.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.133.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70827 (69K) [application/octet-stream]
# Saving to: ‘/tmp/sunspots.csv’
#
# /tmp/sunspots.csv   100%[===================>]  69.17K  --.-KB/s    in 0.001s
#
# 2022-04-04 10:26:34 (61.9 MB/s) - ‘/tmp/sunspots.csv’ saved [70827/70827]

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
time_step = []
sunspots = []

with open('/tmp/sunspots.csv') as csvfile:
  reader = csv.reader(csvfile, delimiter=',')
  next(reader)
  for row in reader:
    sunspots.append(float(row[2]))
    time_step.append(int(row[0]))

series = np.array(sunspots)
time = np.array(time_step)
plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
split_time = 3000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

window_size = 60
batch_size = 32
shuffle_buffer_size = 1000

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)

# %%
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %% [markdown]
# ## Create the model

# %%
def create_model(window_size):
  model = models.Sequential([
    layers.Conv1D(filters=60, kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[None, 1]),
    layers.LSTM(60, return_sequences=True),
    layers.LSTM(60, return_sequences=True),
    layers.Dense(20, input_shape=[window_size], activation="relu"), 
    layers.Dense(10, activation="relu"),
    layers.Dense(1)
  ])
  
  model.compile(loss="mse", 
                optimizer=tf.keras.optimizers.SGD(lr=1e-7, momentum=0.9))
  
  return model

# %%
model = create_model(window_size)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 60)          360
#
#  lstm (LSTM)                 (None, None, 60)          29040
#
#  lstm_1 (LSTM)               (None, None, 60)          29040
#
#  dense (Dense)               (None, None, 20)          1220
#
#  dense_1 (Dense)             (None, None, 10)          210
#
#  dense_2 (Dense)             (None, None, 1)           11
#
# =================================================================
# Total params: 59,881
# Trainable params: 59,881
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %% [markdown]
# ## Train & evaluate the model

# %%
model.fit(train_set, epochs=100)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 21s 38ms/step - loss: 11466.0654
# Epoch 2/100
# 92/92 [==============================] - 3s 32ms/step - loss: 11361.3018
# Epoch 3/100
# 92/92 [==============================] - 3s 32ms/step - loss: 11267.5752
# Epoch 4/100
# 92/92 [==============================] - 3s 32ms/step - loss: 11166.5322
# Epoch 5/100
# 92/92 [==============================] - 3s 32ms/step - loss: 11048.4932
# Epoch 6/100
# 92/92 [==============================] - 3s 32ms/step - loss: 10903.4248
# Epoch 7/100
# 92/92 [==============================] - 3s 32ms/step - loss: 10719.1914
# Epoch 8/100
# 92/92 [==============================] - 3s 32ms/step - loss: 10482.5977
# Epoch 9/100
# 92/92 [==============================] - 3s 32ms/step - loss: 10174.6045
# Epoch 10/100
# 92/92 [==============================] - 3s 31ms/step - loss: 9769.2285
# Epoch 11/100
# 92/92 [==============================] - 3s 32ms/step - loss: 9236.6895
# Epoch 12/100
# 92/92 [==============================] - 3s 32ms/step - loss: 8542.8848
# Epoch 13/100
# 92/92 [==============================] - 3s 32ms/step - loss: 7694.5781
# Epoch 14/100
# 92/92 [==============================] - 3s 32ms/step - loss: 6726.9458
# Epoch 15/100
# 92/92 [==============================] - 3s 32ms/step - loss: 5767.0259
# Epoch 16/100
# 92/92 [==============================] - 3s 32ms/step - loss: 4905.3599
# Epoch 17/100
# 92/92 [==============================] - 3s 32ms/step - loss: 3971.3494
# Epoch 18/100
# 92/92 [==============================] - 3s 32ms/step - loss: 3085.9341
# Epoch 19/100
# 92/92 [==============================] - 3s 35ms/step - loss: 2457.6992
# Epoch 20/100
# 92/92 [==============================] - 3s 32ms/step - loss: 2056.6506
# Epoch 21/100
# 92/92 [==============================] - 3s 32ms/step - loss: 1803.1753
# Epoch 22/100
# 92/92 [==============================] - 3s 32ms/step - loss: 1584.5354
# Epoch 23/100
# 92/92 [==============================] - 3s 32ms/step - loss: 1432.7263
# Epoch 24/100
# 92/92 [==============================] - 3s 32ms/step - loss: 1326.0166
# Epoch 25/100
# 92/92 [==============================] - 3s 33ms/step - loss: 1192.2025
# Epoch 26/100
# 92/92 [==============================] - 3s 32ms/step - loss: 1154.8096
# Epoch 27/100
# 92/92 [==============================] - 3s 32ms/step - loss: 1067.9203
# Epoch 28/100
# 92/92 [==============================] - 3s 32ms/step - loss: 1029.4348
# Epoch 29/100
# 92/92 [==============================] - 3s 32ms/step - loss: 987.6674
# Epoch 30/100
# 92/92 [==============================] - 3s 32ms/step - loss: 941.5469
# Epoch 31/100
# 92/92 [==============================] - 3s 32ms/step - loss: 905.2313
# Epoch 32/100
# 92/92 [==============================] - 3s 32ms/step - loss: 884.8599
# Epoch 33/100
# 92/92 [==============================] - 3s 32ms/step - loss: 889.6013
# Epoch 34/100
# 92/92 [==============================] - 3s 32ms/step - loss: 861.3719
# Epoch 35/100
# 92/92 [==============================] - 3s 32ms/step - loss: 838.6417
# Epoch 36/100
# 92/92 [==============================] - 3s 32ms/step - loss: 833.4053
# Epoch 37/100
# 92/92 [==============================] - 3s 32ms/step - loss: 806.3110
# Epoch 38/100
# 92/92 [==============================] - 3s 32ms/step - loss: 807.9294
# Epoch 39/100
# 92/92 [==============================] - 3s 32ms/step - loss: 791.4857
# Epoch 40/100
# 92/92 [==============================] - 3s 32ms/step - loss: 783.4366
# Epoch 41/100
# 92/92 [==============================] - 3s 32ms/step - loss: 774.0726
# Epoch 42/100
# 92/92 [==============================] - 3s 32ms/step - loss: 761.7271
# Epoch 43/100
# 92/92 [==============================] - 3s 32ms/step - loss: 754.0448
# Epoch 44/100
# 92/92 [==============================] - 3s 32ms/step - loss: 747.7962
# Epoch 45/100
# 92/92 [==============================] - 3s 32ms/step - loss: 741.5422
# Epoch 46/100
# 92/92 [==============================] - 3s 32ms/step - loss: 730.5756
# Epoch 47/100
# 92/92 [==============================] - 3s 32ms/step - loss: 727.9434
# Epoch 48/100
# 92/92 [==============================] - 3s 32ms/step - loss: 723.7772
# Epoch 49/100
# 92/92 [==============================] - 3s 32ms/step - loss: 717.0842
# Epoch 50/100
# 92/92 [==============================] - 3s 32ms/step - loss: 718.1984
# Epoch 51/100
# 92/92 [==============================] - 3s 32ms/step - loss: 710.4045
# Epoch 52/100
# 92/92 [==============================] - 3s 33ms/step - loss: 703.7559
# Epoch 53/100
# 92/92 [==============================] - 3s 32ms/step - loss: 714.9137
# Epoch 54/100
# 92/92 [==============================] - 3s 32ms/step - loss: 709.4753
# Epoch 55/100
# 92/92 [==============================] - 3s 32ms/step - loss: 700.4257
# Epoch 56/100
# 92/92 [==============================] - 3s 32ms/step - loss: 693.7939
# Epoch 57/100
# 92/92 [==============================] - 3s 32ms/step - loss: 688.3555
# Epoch 58/100
# 92/92 [==============================] - 3s 32ms/step - loss: 689.8225
# Epoch 59/100
# 92/92 [==============================] - 3s 32ms/step - loss: 687.0875
# Epoch 60/100
# 92/92 [==============================] - 3s 32ms/step - loss: 686.5643
# Epoch 61/100
# 92/92 [==============================] - 3s 32ms/step - loss: 679.2418
# Epoch 62/100
# 92/92 [==============================] - 3s 32ms/step - loss: 680.4196
# Epoch 63/100
# 92/92 [==============================] - 3s 32ms/step - loss: 692.4838
# Epoch 64/100
# 92/92 [==============================] - 3s 32ms/step - loss: 683.4808
# Epoch 65/100
# 92/92 [==============================] - 3s 32ms/step - loss: 672.0091
# Epoch 66/100
# 92/92 [==============================] - 3s 32ms/step - loss: 670.7888
# Epoch 67/100
# 92/92 [==============================] - 3s 32ms/step - loss: 665.9249
# Epoch 68/100
# 92/92 [==============================] - 3s 32ms/step - loss: 665.8977
# Epoch 69/100
# 92/92 [==============================] - 3s 32ms/step - loss: 673.1093
# Epoch 70/100
# 92/92 [==============================] - 3s 32ms/step - loss: 660.0958
# Epoch 71/100
# 92/92 [==============================] - 3s 32ms/step - loss: 656.6640
# Epoch 72/100
# 92/92 [==============================] - 3s 32ms/step - loss: 664.1458
# Epoch 73/100
# 92/92 [==============================] - 3s 32ms/step - loss: 657.9781
# Epoch 74/100
# 92/92 [==============================] - 3s 32ms/step - loss: 663.1928
# Epoch 75/100
# 92/92 [==============================] - 3s 32ms/step - loss: 657.5917
# Epoch 76/100
# 92/92 [==============================] - 3s 32ms/step - loss: 654.6746
# Epoch 77/100
# 92/92 [==============================] - 3s 32ms/step - loss: 650.0209
# Epoch 78/100
# 92/92 [==============================] - 3s 32ms/step - loss: 647.0498
# Epoch 79/100
# 92/92 [==============================] - 3s 32ms/step - loss: 646.9394
# Epoch 80/100
# 92/92 [==============================] - 3s 32ms/step - loss: 649.2817
# Epoch 81/100
# 92/92 [==============================] - 3s 31ms/step - loss: 643.8477
# Epoch 82/100
# 92/92 [==============================] - 3s 32ms/step - loss: 644.7117
# Epoch 83/100
# 92/92 [==============================] - 3s 32ms/step - loss: 651.6688
# Epoch 84/100
# 92/92 [==============================] - 3s 32ms/step - loss: 640.4551
# Epoch 85/100
# 92/92 [==============================] - 3s 32ms/step - loss: 637.6350
# Epoch 86/100
# 92/92 [==============================] - 3s 32ms/step - loss: 635.9026
# Epoch 87/100
# 92/92 [==============================] - 3s 32ms/step - loss: 635.5335
# Epoch 88/100
# 92/92 [==============================] - 3s 32ms/step - loss: 636.8992
# Epoch 89/100
# 92/92 [==============================] - 3s 32ms/step - loss: 634.5908
# Epoch 90/100
# 92/92 [==============================] - 3s 32ms/step - loss: 636.9443
# Epoch 91/100
# 92/92 [==============================] - 3s 32ms/step - loss: 634.7651
# Epoch 92/100
# 92/92 [==============================] - 3s 32ms/step - loss: 633.6978
# Epoch 93/100
# 92/92 [==============================] - 3s 32ms/step - loss: 628.5424
# Epoch 94/100
# 92/92 [==============================] - 3s 32ms/step - loss: 629.2922
# Epoch 95/100
# 92/92 [==============================] - 3s 32ms/step - loss: 625.2499
# Epoch 96/100
# 92/92 [==============================] - 3s 32ms/step - loss: 636.8247
# Epoch 97/100
# 92/92 [==============================] - 3s 32ms/step - loss: 638.4314
# Epoch 98/100
# 92/92 [==============================] - 3s 32ms/step - loss: 624.0677
# Epoch 99/100
# 92/92 [==============================] - 3s 32ms/step - loss: 624.5707
# Epoch 100/100
# 92/92 [==============================] - 3s 32ms/step - loss: 626.0448

# %%
forecast=[]
for time in range(len(series) - window_size):
  forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)
